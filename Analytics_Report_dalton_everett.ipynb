# %% [markdown]
# # Problem statement
#
# Author: Dalton Lee Everett
#
# Note to grader: I tried my best to show my work with comments.
#
#
# We are an e-commerce sporting goods specific brand that is looking to expand into the GCC region. We have a small database of certain Middle-Eastern countries and it is my job to analyze through historical data on which one would be the best and why.
#
# TO understand this problem we need to find
# - country metrics
# - age demographics
# - region product demand

# %% [markdown]
# ## Problem 1
#
# ### Problem statement
# Focusing on the Gulf Cooperation Council, will be referred to as GCC, are the Arabian Peninsula countries of Saudi Arabia, Qatar, Oman, Kuwait, Bahrain, and United Arab Emirates (UAE). Which one of these countries is best to expand to based off country metrics?
#
# ### Understanding
# Gathering country metrix, such as living cost, quality of life, population information, etc. to create country profiles is the best way to start. Through this, we can conclude which country profile is the best through analysis.

# %% [markdown]
# ## Problem 2
#
# ### Problem statement
# In order to find out some of your customers attributes is by gathering customer demographics to create a profile of your ideal customer. What is your target demographic?
#
# ### Understanding
# To solve this we need to look through all the data to find relevant information. Arguably the most important of all demographics is the age and the first step should be understanding the age structure of your customers.

# %% [markdown]
# ## Problem 3
#
# ### Problem statement
# In-order to know what we need to sell, or advertise, we need to understand the historical demand and what have customers bought from that region. What products does the GCC region order?
#
# ### Understanding
# We need to look at the type of product orders that have been sent to the region. Product information such as the type of product, the amount of the product, and sales from all products are all relevant information for this section.

# %% [markdown]
# # Results
#
# Show the results for each business problem and give your interpretation of those.
#
# This should be in form of a executive summary giving a consise answer to the problem at hand. As long as it is not needed to make the results understandable don't go into methodology here. The problem statement and this section will be the only ones likely to be read by executives for their decision making.
#
# Also, use charts where needed.

# %% [markdown]
# ## Problem 1
# We found that all the countries in the GCC region share similar traits on population metrics. Except when looking at living metrics (appendix 5), Bahrains purchasing power is significantly less than any of the other countries metrics. The life quality of Kuwait is also significintly lower than the rest. We can fore-go exploring the option of expanding into either of those two countries based on those metrics.

# %% [markdown]
# ## Problem 2
# We found that the age structure of the three remaining GCC countries to be very close to each other. Except for Saudi Arabia (appendix 2), which has 10% difference in 0 to 14 (children) and 15 to 64 (adults) has a very favorable customer age mix when looking at the amount of children their population consist of. Through this, if expanding to saudi arabia we should have a slight focus on children but not immensely.
#
# Of the three remaining countries we were doing analysis of (please ready rest of problems to have a better understanding) Saudi Arabia is the laregst. This is without surprise since it has been a longer existing country and greater land size. The fastest growth is from Qatar (maybe why they had the World Cup), and UAE has the largest median age.

# %% [markdown]
# ## Problem 3
# Searching to find the most common products between all the countries was the hardest part. At this point, we are still debating about expanding to Saudi Arabia, Qatar, UAE, or Oman. Comparing sales on appendix 4, Oman has significantly lower sales than Saudi Arabia, Qatar, and the UAE. We can futher conclude that our biggest customer base is in saudi arabia with the total volumn of sales as well as the types of products they order. The most popular orders are fishing and cleats appendix 3.

# %% [markdown]
# ## Executive Summary
#
# Through thoughtful analysis and elaborate decision making, I have concluded that we should expand our marketing campaign into the into Saudi Arabia and Qatar. Having our focus on Saudi Arabia will help our company take advantage of the rapidly growing Arabian countries.
#
# Qatar is seeing great growth (highest of the three countries) as well as the second highest sales and products bought. Along with that, they have the highest purchasing power and cost of living of all the GCC countries, and highest quality of life when compared against Saudi and UAE.
#
# Analyzing product, we have concluded that we should focus our advertising on shoes. Both countries top three most ordered products were types of shoes: cleats, mens shoes, and females shoes. There is no correlation between any three of those products, so we do not need to cross advertise. Instead, we should have intervalled advertising campaigns that highlight our products one-by-one instead of putting all three products in-front of our customer in hope that they will buy it.
#
#
# Saudi Arabia is the market we should expand our focus on, but not without having Qatar in our focus as well. There is no correlation between any two products, so we do not need to worry about offering a paired discount to attract and retain new customers. instead, we should be focusing on cleats as well as mens and female shoes with our advertisement campaign.

# %% [markdown]
# ## Appendix

# %%
print('-'*100)
print('(1) Population metrics')
# Out:
# ----------------------------------------------------------------------------------------------------
# (1) Population metrics

# %%
gcc_metrix_9
# Out:
#                              pop  %change  med_age  migrants  living_cost  \
# country
# Qatar                  2889284.0     1.73     32.0   40000.0        64.04
# Saudi Arabia          34905942.0     1.59     32.0  134979.0        48.34
# United Arab Emirates   9910892.0     1.23     33.0   40000.0        61.98
#
#                       purch_power  life_quality
# country
# Qatar                      111.69        162.29
# Saudi Arabia               100.00        150.56
# United Arab Emirates        91.58        156.67

# %%
print('-'*100)
print('(2) Age structure')
# Out:
# ----------------------------------------------------------------------------------------------------
# (2) Age structure

# %%
gcc_age_s_3
# Out:
#                   country 0_to_14 15_to_64 64_and_above
# 148          Saudi Arabia  25.20%   71.50%           3%
# 189                 Qatar  13.90%   84.80%           1%
# 190  United Arab Emirates  13.90%   85.00%           1%

# %%
print('-'*100)
print('(3) Related products')
# Out:
# ----------------------------------------------------------------------------------------------------
# (3) Related products

# %%
merged_df_v
# Out:
# product_category  sales_uae  sales_qatar  saudi_sales
# product_category
# camping_hiking            2            1           68
# cleats                    5            6          122
# electronics               1            2           18
# fishing                   5            5           82
# hunting_shooting          1            1            1
# in_out_games              2            3           99
# men_shoes                 3            5          114
# shop_by_sports            1            3           65
# water_sports              2            3           77
# women_shoes               3            7          103

# %%
print('-'*100)
print('(4) Sales ($) per GCC country')
# Out:
# ----------------------------------------------------------------------------------------------------
# (4) Sales ($) per GCC country

# %%
df_gcc_sales
# Out:
#             order_country     sales
# 0            Arabia Saudí  163169.0
# 5                   Qatar    7725.0
# 2  Emiratos Árabes Unidos    5691.0
# 4                    Omán    1375.0
# 1                  Baréin     530.0
# 3                  Kuwait     335.0

# %%
print('-'*100)
print('(5) Living metrics for GCC')
# Out:
# ----------------------------------------------------------------------------------------------------
# (5) Living metrics for GCC

# %%
merged_lc_lq
# Out:
#                 country  living_cost  purch_power  life_quality
# 0                 Qatar        64.04       111.69        162.29
# 1          Saudi Arabia        48.34       100.00        150.56
# 2  United Arab Emirates        61.98        91.58        156.67
# 3                Kuwait        50.37        85.59        115.75
# 4                  Oman        49.28        80.97        167.09
# 5               Bahrain        58.94        57.88        156.67

# %% [markdown]
# # Assumptions made
#
# You will often work with limited information. This might be because you don't have the time to gather the needed, or because the information is not available. It is ok to make assumptions, but it needs to be made clear that you did so and why.
#
# State any assumptions and the reasons they were made here.

# %% [markdown]
# ## Problem 1
#
# Sharing similar geographical regions, societal customs, religion, politics, and way of life style, it is safe to say that the markets are the same and customers act similarly. The GCC region has seen immense growth over the past 20 years, and only expected to continue to grow.
#
# PwC. (2023, February 21). Five GCC economic themes to watch in 2023. PwC Middle East Blog. https://www.pwc.com/m1/en/blog/five-gcc-economic-themes-to-watch-in-2023.html

# %% [markdown]
# ## Problem 2
# When looking for age structure we can make a safe assumption that senior citizens are not buying sporting goods. Conversely, we can suspect that children are consuming more sporting goods or at least their parents are buying them for their use. Therefore, as an on-line retailer we can target the parents with goods for children. To the same point, we know that adults are buying goods for themselves as well.
#
# We can also assume that the age structure of Saudi Arabia is partially due to the fact that is has been a much longer running society than Qatar and UAE. Only recently (with the new-found oil) have the other two regions started attracting foreign investors and promoting economic growth.
#
# In many cultures the time when a child comes an adult is very young. This is true in the middle east, so we are assuming all those between 15 to 64 age are adults.

# %% [markdown]
# ## Problem 3
#
# I took the assumption that products, which are commonly bought in one region, can be expanded to a nearby region using the same supply chain and can experience profit gains since we are not taking on an entirely new supply chain cost. Instead, we are building off an existing supply chain that can handle an increase of products and can be shipped to nearby regions for minimal cost increase.

# %% [markdown]
# # Limitations
#
# In most cases your answers to the business questions will have some limitations. They might for example not be generalizable, but only valid for a certain case. Describe any limitations your results have.

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ## Problem 2
#
# When finding the age, or other demographics, of the GCC populations the only relevant information i found was about the age structure. This age structure was not as detailed as i would like since it was only three groups: children, adults, and senior citizen with adults being anything between the ages of 15 to 64. If they divided the ages more or if they had the ages then we could narrow down more.

# %% [markdown]
# ## Problem 3
#
# The datasets we have about products are limited in the amount we have for the GCC region. This forced us to omit some countries based on the fact we did not have historical information to base any recommendations on.
#
# When I narrowed down my recommendations from the 6 GCC countries down to the 3 (UAE, Saudi Arabia, and Qatar) there were only so many products that were sold in all three of those countries.

# %% [markdown]
# # Data
#
# In this section you need to describe the data used, its sources, data quality, data constraints and the results of your EDA. This is likely one of the longer sections as it needs to go into detail here. It is important that the reader of your report is able to follow your thinking. Any code cells need to be executable top-to-bottom.
#
# For each dataset the following should be answered:
#
# - Why was this dataset used?
# - For which problems was it used?
# - Data source including link/code to get the data. Timestamps if the data is a snapshot.
# - EDA
#     - Data quality
#     - constraints on the data
#
#
#
#
# This holds everything except for the code that solves the problem:
#
# grouping, filtering, whatever you need to do to answer your question

# %% [markdown]
# ## Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# '''
# These are the files that are directly unzipped inside the file A1. I will go through every one to see the info.
#
# (1) 2012 Retail Sales by Store Type within Product Category
#     - possibly useful, but not sure because the data looks very messy
#
# (2) Amazon Sale Report
#     - a lot of data, but it doesnt look to useful to me. maybe later i can use it,
#       but there is nothing meaningful yet.
#
# (3) amazon_co-ecommerce_sample
#     - this is just survey answers from individual orders and will not be useful
#
# (4) cost-of-living_v2
#     - will not be using this because the columns do not make anysense and there is no relevant data
#     - use the first volumn that can be fown futher down
#
# (5) data
#     - i have no idea what this could be used for. This will not be useful in my analysis
#       and can be left out
#
# (6) DataCoSupplyChainDataset
#     -Y, there are a lot of useful columns that can be used with this. I can see this being
#       extremely useful for answering my problem and build on my findings
#
# (7) glassdoor_jobs
#     - Not useful as a list of jobs and job description does not provide any useful information
#
# (8) International sale Report
#     - this does nto have useful information. Just individual customer orders and
#       useless information about a single product order.
#
# (9) May-2022
#     - Looks like it could be useful because it has competitors in the columns but
#       it is useless information that provides no purpose
#
# (10) metadata
#     - this information is not useful in my findings
#
# (11) NBA Finals and MVP
#     - Cool and interesting data, but this does not provide any relevant information
#
# (12) noon
#     - This has a lot of orders from noon and other companies. This is not useful in my findings
#
# (13) Sale Report
#     - Not too useful and it seems to be the same exact file as sales transaction v.4a
#
# (14) Sales Transaction v.4a
#     - could be useful if i want to see the amount of a certain clothing category is popular
#
# (15) AustraliaChains
#     - this does not provide me any relevant information
#
# (16) countries
#     - Does not provide me with anything useful other than countries and random geographical information
#
# (17) zara_us_sample_data
#     - Zara is a clothing department store, this doesnt give us anything relevant
#
# '''

# %%
'(1) 2012 Retail Sales by Store Type within Product Category'
retail_type_in_product_cat_2021 = pd.read_csv('2012 Retail Sales by Store Type within Product Category.csv')
retail_type_in_product_cat_2021.head()
#lets see what it is descending
retail_type_in_product_cat_2021_sort = retail_type_in_product_cat_2021.sort_values(by='Sales ($1,000)', ascending = True)
retail_type_in_product_cat_2021_sort.head()
# Out:
#       index Products and services code  \
# 8301   8301                      20330
# 4217   4217                      20330
# 8898   8898                      20440
# 9901   9901                      20758
# 5655   5655                      20758
#
#                   Meaning of Products and services code  2012 NAICS code  \
# 8301  Audio equipment, musical instruments (new & us...         448120.0
# 4217  Audio equipment, musical instruments (new & us...          44812.0
# 8898                  Photographic equipment & supplies         451212.0
# 9901                         Infant & booster car seats         441110.0
# 5655                         Infant & booster car seats          44111.0
#
#       Code length   Meaning of 2012 NAICS code  Number of establishments  \
# 8301          6.0      Women's clothing stores                         9
# 4217          5.0      Women's clothing stores                         9
# ...

# %%
'(2) Amazon Sale Report'
#this is just survey answers from individual orders
amazon_sale_report = pd.read_csv('Amazon Sale Report.csv', low_memory = False)
amazon_sale_report.head()
amazon_sale_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
'(3) amazon_co-ecommerce_sample'
amazon_co_commerce_sample = pd.read_csv('amazon_co-ecommerce_sample.csv', low_memory = False)
amazon_co_commerce_sample.info()
amazon_co_commerce_sample.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   uniq_id                                      10000 non-null  object
#  1   product_name                                 10000 non-null  object
#  2   manufacturer                                 9993 non-null   object
#  3   price                                        8565 non-null   object
#  4   number_available_in_stock                    7500 non-null   object
#  5   number_of_reviews                            9982 non-null   object
#  6   number_of_answered_questions                 9235 non-null   float64
#  7   average_review_rating                        9982 non-null   object
#  8   amazon_category_and_sub_category             9310 non-null   object
# ...

# %%
'(4) cost-of-living_v2'
cost_of_living_v2 = pd.read_csv('cost-of-living_v2.csv')
cost_of_living_v2.head()
#this doesnt make any sense and the columns have no meaning
# Out:
#         city      country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 0      Seoul  South Korea  7.68  53.78  6.15  3.07  4.99  3.93  1.48  0.79
# 1   Shanghai        China  5.69  39.86  5.69  1.14  4.27  3.98  0.53  0.33
# 2  Guangzhou        China  4.13  28.47  4.98  0.85  1.71  3.54  0.44  0.33
# 3     Mumbai        India  3.68  18.42  3.68  2.46  4.30  2.48  0.48  0.19
# 4      Delhi        India  4.91  22.11  4.30  1.84  3.68  1.77  0.49  0.19
#
#    ...     x47      x48     x49      x50      x51       x52       x53  \
# 0  ...  110.36   742.54  557.52  2669.12  1731.08  22067.70  10971.90
# 1  ...  123.51  1091.93  569.88  2952.70  1561.59  17746.11   9416.35
# 2  ...   43.89   533.28  317.45  1242.24   688.05  12892.82   5427.45
# 3  ...   41.17   522.40  294.05  1411.12   699.80   6092.45   2777.51
# 4  ...   36.50   229.84  135.31   601.02   329.15   2506.73   1036.74
#
#        x54   x55  data_quality
# 0  2689.62  3.47             1
# ...

# %%
'(5) data'
data = pd.read_csv('data.csv', low_memory = False)
data.head(100)
# Out:
#     time_series_code        date  value
# 0   BOPGS_BAL_US_adj  1992-01-01  -2026
# 1   BOPGS_EXP_US_adj  1992-01-01  50251
# 2   BOPGS_IMP_US_adj  1992-01-01  52277
# 3        BOPG_BAL_US  1992-01-01  -6210
# 4        BOPG_EXP_US  1992-01-01  33953
# ..               ...         ...    ...
# 95       BOPG_IMP_US  1993-04-01  48546
# 96  BOPGS_BAL_US_adj  1993-05-01  -4369
# 97  BOPGS_EXP_US_adj  1993-05-01  54229
# 98  BOPGS_IMP_US_adj  1993-05-01  58598
# 99       BOPG_BAL_US  1993-05-01  -7935
#
# [100 rows x 3 columns]

# %%
'(6) DataCoSupplyChainDataset'
### useful ###

DataCoSupplyChainDataset = pd.read_csv('DataCoSupplyChainDataset.csv', low_memory = False, encoding='ISO-8859-1' )
DataCoSupplyChainDataset.head()
DataCoSupplyChainDataset.info()

#yeahhhh this will be useful
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
'(7) glassdoor_jobs'
glassdoor_jobs = pd.read_csv('glassdoor_jobs.csv', low_memory = False)
glassdoor_jobs.head()
#looks useless. I dont know how a glassdoor jobs page can help me in my findings
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
'(8) International sale Report'
international_sale_report = pd.read_csv('International sale Report.csv', low_memory = False)
international_sale_report.head()
# Out:
#    index      DATE  Months            CUSTOMER    Style             SKU Size  \
# 0      0  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L    L
# 1      1  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL   XL
# 2      2  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL  XXL
# 3      3  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L    L
# 4      4  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L    L
#
#     PCS    RATE GROSS AMT
# 0  1.00  616.56    617.00
# 1  1.00  616.56    617.00
# 2  1.00  616.56    617.00
# 3  1.00  616.56    617.00
# 4  1.00  616.56    617.00

# %%
'(9) May-2022'
may_2022 = pd.read_csv('May-2022.csv', low_memory = False)
may_2022.head()
# Out:
#    index             Sku    Style Id  Catalog Category Weight   TP MRP Old  \
# 0      0    Os206_3141_S  Os206_3141  Moments    Kurta    0.3  538    2178
# 1      1    Os206_3141_M  Os206_3141  Moments    Kurta    0.3  538    2178
# 2      2    Os206_3141_L  Os206_3141  Moments    Kurta    0.3  538    2178
# 3      3   Os206_3141_XL  Os206_3141  Moments    Kurta    0.3  538    2178
# 4      4  Os206_3141_2XL  Os206_3141  Moments    Kurta    0.3  538    2178
#
#   Final MRP Old Ajio MRP Amazon MRP Amazon FBA MRP Flipkart MRP Limeroad MRP  \
# 0          2295     2295       2295           2295         2295         2295
# 1          2295     2295       2295           2295         2295         2295
# 2          2295     2295       2295           2295         2295         2295
# 3          2295     2295       2295           2295         2295         2295
# 4          2295     2295       2295           2295         2295         2295
#
#   Myntra MRP Paytm MRP Snapdeal MRP
# ...

# %%
'(10) metadata'
metadata = pd.read_csv('metadata.csv', low_memory = False)
metadata.head()
metadata.describe()
#nothing useful that can help my findings and problem
# Out:
#        category_level        is_adj
# count    11106.000000  11106.000000
# mean         1.033495      0.145867
# std          1.068881      0.352989
# min          0.000000      0.000000
# 25%          0.000000      0.000000
# 50%          1.000000      0.000000
# 75%          2.000000      0.000000
# max          3.000000      1.000000

# %%
'(11) NBA Finals and MVP'
nba_finals_and_mvp = pd.read_csv('NBA Finals and MVP.csv', low_memory = False)
nba_finals_and_mvp.head()
#interesting but nothing
# Out:
#    index  Year    Western Champion    Eastern Champion Result  \
# 0      0  1950  Minneapolis Lakers  Syracuse Nationals    4–2
# 1      1  1951    Rochester Royals     New York Knicks    4–3
# 2      2  1952  Minneapolis Lakers     New York Knicks    4–3
# 3      3  1953  Minneapolis Lakers     New York Knicks    4–1
# 4      4  1954  Minneapolis Lakers  Syracuse Nationals    4–3
#
#          NBA Champion   NBA Vice-Champion  Final Sweep ? MVP Name  \
# 0  Minneapolis Lakers  Syracuse Nationals          False      NaN
# 1    Rochester Royals     New York Knicks          False      NaN
# 2  Minneapolis Lakers     New York Knicks          False      NaN
# 3  Minneapolis Lakers     New York Knicks          False      NaN
# 4  Minneapolis Lakers  Syracuse Nationals          False      NaN
#
#    MVP Height (m)  MVP Height (ft) MVP Position MVP Team MVP Nationality  \
# 0             NaN              NaN          NaN      NaN             NaN
# ...

# %%
'(12) noon'
noon = pd.read_csv('noon.csv', low_memory = False)
noon.head()
# Out:
#                                                 name     brand sold_by  \
# 0  Colorblock Logo T-Shirt Blue Void/Game Royal/W...      Nike    noon
# 1                Futura Swoosh Bra Pink Quartz/White      Nike    noon
# 2                             Franchise Shorts Black      Nike  Namshi
# 3                          3 Piece Inner Socks Black  SKECHERS  Namshi
# 4                    Run It Climalite Vest Glow Blue    adidas    noon
#
#    old_price  current_price  saving section                       color  \
# 0      129.0          103.0    26.0    Boys  Blue Void/Game Royal/White
# 1      159.0          127.0    32.0   Women           Pink Quartz/White
# 2      169.0          169.0     0.0     Men                       Black
# 3       35.0           35.0     0.0   Women                       Black
# 4      139.0          139.0     0.0   Women                   Glow Blue
#
#           material
# 0              NaN
# 1              NaN
# 2        Polyester
# 3      Combination
# ...

# %%
'(13) Sale Report'
sale_report = pd.read_csv('Sale Report.csv', low_memory = False)
sale_report.head()
sale_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9271 entries, 0 to 9270
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       9271 non-null   int64
#  1   SKU Code    9188 non-null   object
#  2   Design No.  9235 non-null   object
#  3   Stock       9235 non-null   float64
#  4   Category    9226 non-null   object
#  5   Size        9235 non-null   object
#  6   Color       9226 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 507.1+ KB

# %%
'(14) Sales Transaction v.4a'
### mayyyybeee? ###

sale_report = pd.read_csv('Sale Report.csv', low_memory = False)
sale_report.head()
sale_report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9271 entries, 0 to 9270
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       9271 non-null   int64
#  1   SKU Code    9188 non-null   object
#  2   Design No.  9235 non-null   object
#  3   Stock       9235 non-null   float64
#  4   Category    9226 non-null   object
#  5   Size        9235 non-null   object
#  6   Color       9226 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 507.1+ KB

# %%
'(15) AustraliaChains'
## i dont think this is going to help me with anything

australia_chains = pd.read_excel('AustraliaChains.xlsx')
australia_chains.head()
# Out:
#         Date Chain  Postcode   Category  Total Units  Sale Price  Cost Price  \
# 0 2016-01-01  Nike      2650       Home          175        2.78        6.35
# 1 2016-01-01  Nike      3550  Groceries          908        0.61        0.93
# 2 2016-01-01  Nike      4053       Home            1      500.00      750.00
# 3 2016-01-01  Nike      3076  Groceries          714        1.14        1.46
# 4 2016-01-01  Nike      2031  Groceries           65        0.48        3.90
#
#    Unnamed: 7 Unnamed: 8
# 0         NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN

# %%
'(17) countries'
## Nothing helpful

countries = pd.read_json('countries.json')
countries.head()
# Out:
#                                                                          Afghanistan  \
# url                                https://www.cia.gov/the-world-factbook/countri...
# Introduction: Background           Ahmad Shah DURRANI unified the Pashtun tribes ...
# Geography: Location                Southern Asia, north and west of Pakistan, eas...
# Geography: Geographic coordinates                                   33 00 N, 65 00 E
# Geography: Map references                                                       Asia
#
#                                                                             Akrotiri  \
# url                                https://www.cia.gov/the-world-factbook/countri...
# Introduction: Background           By terms of the 1960 Treaty of Establishment t...
# Geography: Location                Eastern Mediterranean, peninsula on the southw...
# Geography: Geographic coordinates                                   34 37 N, 32 58 E
# ...

# %%
'(18) zara_us_sample_data'
## Nothing helpful

zara_us_sample_data = pd.read_json('zara_us_sample_data.json')
zara_us_sample_data.head()x
# Out:
#                                                  url language  \
# 0  https://www.zara.com/us/en/satin-effect-corset...    en-US
# 1  https://www.zara.com/us/en/long-print-dress-p0...    en-US
# 2  https://www.zara.com/us/en/steel-kitchen-sciss...    en-US
# 3  https://www.zara.com/us/en/linen-blend-striped...    en-US
# 4  https://www.zara.com/us/en/chiffon-organizer-w...    en-US
#
#                                      name               sku               mpn  \
# 0            SATIN EFFECT CORSET BODYSUIT   128666521-966-2   128666521-966-2
# 1                        LONG PRINT DRESS   142448983-701-1   142448983-701-1
# 2                  STEEL KITCHEN SCISSORS  125067259-220-99  125067259-220-99
# 3           LINEN BLEND STRIPED ORGANIZER  135325938-737-99  135325938-737-99
# 4  CHIFFON ORGANIZER WITH MOONS AND STARS  138551470-727-99  138551470-727-99
#
#       brand                                        description  price  \
# ...

# %%
'(16) countries'
### really nothing in here other than if i want to make a geography quiz #

countries = pd.read_json('countries.json')
countries.head()
countries.info()

# %%
'(17) zara_us_sample_data'
## doesnt provide relevant information ##

zara_us_sample_data = pd.read_json('zara_us_sample_data.json')
zara_us_sample_data.head()

# %% [markdown]
# ^^^^^^^^^^^^^^^^^
# Everything above is only dealing with the files within the A1 folder
#
#
#  Below is just random code i wrote to get an idea of some files before determining if they were useful

# %% [markdown]
# Below i will have descriptions of the folders and if they were or were not useful
#
# - Business and Industry Report
#     - There was no relevant data that i could have used within the dataset
#
#
# - Consumer Price Index
#     - Does not provide any useful information. I do not need consumer prices for my analysis. Even if i did there\
#         were not specific to the middle east or GCC countries
#
#
# - NAICS
#     - Did not present useful information. I do not need the various NAICS codes for my analysis
#
#
# - World Bank
#     - Extremely useful, i used three files within this set
#         - population_by_country_2020
#             - this one was better than the other one (country_pop)
#         - Coutries age structure
#         - Cost of living index by country
#     - I used these to create the country information to get metrix of countries
#     - Age structure to select the type of demographics that i could target
#     - i did not use much of the other information as they were not relevant to my\
#         question and would not add value to my findings
#     - Examples why:
#         - weo2020electricityaccessdatabase, i did not need to figure out the amount of people who do not have access
#         - List of developing countries, fertility rate, internet users of africa, etc. There is alot of \
#           useless information that does not add any value to my findings

# %%
#lets see if country pop has anything useful
country_pop = pd.read_csv('World Bank/country_population.csv')
country_pop.head()
#ehh, not really.

#lets see if the population-by-country-2020 is better
country_pop_2020 = pd.read_csv('World Bank/population-by-country-2020/population_by_country_2020.csv')
country_pop_2020.head()
#yes this is much better
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
#does country population density give us anything interesting?
country_pop_density = pd.read_csv('World Bank//countries-dataset-2020/Pupulation density by countries.csv')
#just shows us the density of countries and not the cities, which would have been helpful

# %%
'''
This dataset may be helpful to see the regions in which we want to grow the highest with largest potential market
'''#used to find age structur

# lets look at country age structures
country_age_structure = pd.read_csv('World Bank//countries-dataset-2020/Coutries age structure.csv')
#who has the largest % of 15 to 64?
country_age_structure_sorted = country_age_structure.sort_values(by='Age 15 to 64 Years', ascending = False)
country_age_structure_sorted.head(25)
#Emirates has highest, followed by GCC / Arabian Penninsula region


#what about largest % of children?
country_age_structure_sorted = country_age_structure.sort_values(by='Age 15 to 64 Years', ascending = False)
country_age_structure_sorted.head(25)
#Niger has highest, followed by other african countries
# Out:
#                   Country Age 0 to 14 Years Age 15 to 64 Years  \
# 190  United Arab Emirates            13.90%             85.00%
# 189                 Qatar            13.90%             84.80%
# 184               Bahrain            19.70%             77.90%
# 66                  Macau            13.40%             76.90%
# 187                Kuwait            21.10%             76.60%
# 182                  Oman            21.80%             75.80%
# 62                Moldova            15.70%             73.40%
# 50                 Taiwan            13.12%             73.02%
# 48            South Korea            13.50%             72.60%
# 130              Maldives            23.40%             72.50%
# 117                Brunei            23.00%             72.40%
# 33              Hong Kong            11.50%             72.20%
# 54              Singapore            15.00%             72.10%
# 63                  China            17.70%             71.70%
# ...

# %%
'Cost of living index by country 2020'
##Now lets see the cost of living index with local purchasing power
#there is an updated version but this is the better one
country_cost_of_living = pd.read_csv('World Bank//countries-dataset-2020/Cost of living index by country 2020.csv')
country_cost_of_living_sorted = country_cost_of_living.sort_values(by='Local Purchasing Power Index', ascending= False)
country_cost_of_living_sorted.head(25)

#lets put this to use
# Out:
#                  Country  Cost of Living Index  Rent Index  \
# 0            Switzerland                122.40       50.25
# 30                 Qatar                 64.04       47.44
# 19         United States                 71.05       40.32
# 15             Australia                 73.54       34.86
# 6             Luxembourg                 81.89       54.92
# 28               Germany                 65.26       27.06
# 22                Sweden                 69.85       25.90
# 4                Denmark                 83.00       31.92
# 56          Saudi Arabia                 48.34       11.39
# 21               Finland                 70.29       26.16
# 23                Canada                 67.62       30.73
# 16           New Zealand                 72.53       32.09
# 26        United Kingdom                 67.28       29.85
# 31  United Arab Emirates                 61.98       41.07
# 14           Netherlands                 73.75       35.18
# ...

# %%
'World Bank//weo2020electricityaccessdatabase'
#there is a middle east folder in here and was curious if it was useful

me_electric_access = pd.read_csv('World Bank//weo2020electricityaccessdatabase/Middle East-Table 1.csv')

me_electric_access.head()
#not useful
# Out:
#    Unnamed: 0  Unnamed: 1                              Unnamed: 2  \
# 0         NaN         NaN                                     NaN
# 1         NaN         NaN  Source: IEA, World Energy Outlook-2020
# 2         NaN         NaN   Electricity Access in the Middle East
# 3         NaN         NaN                                     NaN
# 4         NaN         NaN                                     NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3  Proportion of the population with access to el...        NaN        NaN
# 4                                           National        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# ^^^^^^^^  everything above is random findings and searching through files

# %% [markdown]
# # country metrix

# %%
'GCC country population info'
#    - Saudi Arabia
#    - Kuwait
#    - United Arab Emirates
#    - Bahrain
#    - Qatar
#    - Oman

#lets see the largest GCC countries
df_pop = pd.DataFrame(country_pop_2020.copy())
df_pop


#renaming / selecting data
df_pop['country'] = df_pop ['Country (or dependency)']
df_pop['pop'] = df_pop['Population (2020)']
df_pop['%change'] = df_pop['Yearly Change']
df_pop['med_age'] = df_pop['Med. Age']
df_pop['migrants'] = df_pop['Migrants (net)']

#drop columns
df_pop_market = df_pop.drop(columns=['Country (or dependency)', 'Population (2020)', 'Yearly Change',\
                                     'Med. Age', 'Net Change', 'Density (P/Km²)', 'Land Area (Km²)',\
                                     'Urban Pop %', 'World Share', 'Fert. Rate', 'Migrants (net)'])

#fix the datatype. pop is not a float
df_pop_market['pop'] = df_pop_market['pop'].astype(float)
df_pop_market['pop'] = df_pop_market['pop'].map('{:,.0f}'.format)
df_pop_market['migrants'] = df_pop_market['migrants'].map('{:,.0f}'.format)

df_pop_market.head()

#now i want to search for only the countries within the GCC region

#I want to make it work on one country before i try all 6 and also to see which
# ones not in database
saudi_pop_market = df_pop_market.loc[df_pop_market['country'] == 'Saudi Arabia', :]
kuwait_pop_market = df_pop_market.loc[df_pop_market['country'] == 'Kuwait', :]
uae_pop_market = df_pop_market.loc[df_pop_market['country'] == 'United Arab Emirates', :]
bahrain_pop_market = df_pop_market.loc[df_pop_market['country'] == 'Bahrain', :]
qatar_pop_market = df_pop_market.loc[df_pop_market['country'] == 'Qatar', :]
oman_pop_market = df_pop_market.loc[df_pop_market['country'] == 'Oman', :]
# all 6 countries are in the database

#now lets look at them together
gcc_pop_market = df_pop_market.loc[df_pop_market['country'].isin(['Saudi Arabia', 'United Arab Emirates', 'Qatar', 'Kuwait', 'Bahrain', 'Oman'])]
                                                                
    
gcc_pop_market =gcc_pop_market.sort_values(by='%change', ascending=False)

print('-'*50)
print('population info')
print('-'*50)
print(f"""
{gcc_pop_market}

This gives us the population of the GCC countries ordered by %change

""")
# Out:
# --------------------------------------------------
# population info
# --------------------------------------------------
#
#                   country         pop %change med_age migrants
# 151               Bahrain   1,711,057  3.68 %      32   47,800
# 119                  Oman   5,128,058  2.65 %      31   87,400
# 138                 Qatar   2,889,284  1.73 %      32   40,000
# 40           Saudi Arabia  34,905,942  1.59 %      32  134,979
# 128                Kuwait   4,281,320  1.51 %      37   39,520
# 92   United Arab Emirates   9,910,892  1.23 %      33   40,000
#
# This gives us the population of the GCC countries ordered by %change

# %%
print('-'*50)
print('population info')
print('-'*50)
print(f"""
{qatar_pop_market}

This gives us the population of the GCC countries ordered by %change

""")
# Out:
# --------------------------------------------------
# population info
# --------------------------------------------------
#
#     country        pop %change med_age migrants
# 138   Qatar  2,889,284  1.73 %      32   40,000
#
# This gives us the population of the GCC countries ordered by %change

# %%
gcc_pop_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 151 to 92
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   6 non-null      object
#  1   pop       6 non-null      object
#  2   %change   6 non-null      object
#  3   med_age   6 non-null      object
#  4   migrants  6 non-null      object
# dtypes: object(5)
# memory usage: 288.0+ bytes

# %%
'Quality of life'

quality_of_life = pd.read_csv('World Bank//countries-dataset-2020/Quality of life index by countries 2020.csv')
quality_of_life.head()

df_lq = pd.DataFrame(quality_of_life.copy())
df_lq

# rename / select the data
df_lq['country'] = df_lq ['Country']
df_lq['life_quality'] = df_lq['Quality of Life Index']
#dropping the last 2 becasue the next dataset has them
df_lq['purch_power'] = df_lq['Purchasing Power Index']
df_lq['living_cost'] = df_lq['Cost of Living Index']
df_lq

#dropping the ones we dont want
#since purchasing power and living cost are in the next table we can drop those
df_lq = df_lq.drop(columns=['Country','Quality of Life Index','Purchasing Power Index',\
                                     'Safety Index','Health Care Index','Cost of Living Index',\
                                     'Property Price to Income Ratio','Traffic Commute Time Index',\
                                     'Pollution Index','Climate Index','purch_power','living_cost'])
#now we select the GCC countries
#lets see if any are not in data

saudi_lq = df_lq.loc[df_lq['country'] == 'Saudi Arabia', :]
kuwait_lq = df_lq.loc[df_lq['country'] == 'Kuwait', :]
uae_lq = df_lq.loc[df_lq['country'] == 'United Arab Emirates', :]
bahrain_lq = df_lq.loc[df_lq['country'] == 'Bahrain', :]
qatar_lq = df_lq.loc[df_lq['country'] == 'Qatar', :]
oman_lq = df_lq.loc[df_lq['country'] == 'Oman', :]
#bahrain is not represented
# so lets add Bahrain to the list and give it the median


#first, lets see the 5 together
gcc_lq = df_lq.loc[df_lq['country'].isin(['Saudi Arabia', 'United Arab Emirates', 'Qatar', 'Kuwait', 'Oman'])]

#here i add the column to have Bahrain
#first i have to get the median of these countries so that I can
# assign Bahrain a value

#median
# i am using median because there is an outlier (Kuwait) that impacts the mean
median_lq = gcc_lq['life_quality'].median()

#make a dataset of bahrain
bahrain_data_lq = {'country': 'Bahrain', 'life_quality': median_lq}
df_bahrain_data_lq = pd.DataFrame(bahrain_data_lq, index=[0])

#add it in
gcc_lq = gcc_lq.append([gcc_lq, df_bahrain_data_lq], ignore_index=True)
gcc_lq

#order them
gcc_lq =gcc_lq.sort_values(by='life_quality', ascending=False)

#there are duplicates so i have to delete those
gcc_lq = gcc_lq.drop_duplicates(subset='country', keep='first')

print('-'*50)
print('Quality of life')
print('-'*50)
print(f"""
{gcc_lq}

This gives us quality of life information for GCC countries


""")
# Out:
# --------------------------------------------------
# Quality of life
# --------------------------------------------------
#
#                  country  life_quality
# 0                   Oman        167.09
# 1                  Qatar        162.29
# 2   United Arab Emirates        156.67
# 10               Bahrain        156.67
# 3           Saudi Arabia        150.56
# 4                 Kuwait        115.75
#
# This gives us quality of life information for GCC countries
# /var/folders/8q/6hg097sj4t58f_76zj__fzlc0000gn/T/ipykernel_6448/3533851075.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gcc_lq = gcc_lq.append([gcc_lq, df_bahrain_data_lq], ignore_index=True)

# %%
#order them
gcc_lq =gcc_lq.sort_values(by='life_quality', ascending=False)

print('-'*50)
print('Quality of life')
print('-'*50)
print(f"""
{gcc_lq}

This gives us quality of life information for GCC countries


""")
# Out:
# --------------------------------------------------
# Quality of life
# --------------------------------------------------
#
#                  country  life_quality
# 0                   Oman        167.09
# 1                  Qatar        162.29
# 2   United Arab Emirates        156.67
# 10               Bahrain        156.67
# 3           Saudi Arabia        150.56
# 4                 Kuwait        115.75
#
# This gives us quality of life information for GCC countries

# %%
#'Cost of living'
#
# this gives the quality of life and purchase power and living cost for  
#    all the countries
#
df_lc = pd.DataFrame(country_cost_of_living_sorted.copy())
df_lc

# rename / select the data
df_lc['country'] = df_lc['Country']
df_lc['living_cost'] = df_lc['Cost of Living Index']
df_lc['purch_power'] = df_lc['Local Purchasing Power Index']
df_lc

#dropping the ones we dont want
df_lc = df_lc.drop(columns=['Country','Cost of Living Index','Rent Index', 'Cost of Living Plus Rent Index',\
                            'Groceries Index','Restaurant Price Index','Local Purchasing Power Index'])

#now we select the GCC countries
#lets see if any are not in data

saudi_lc = df_lc.loc[df_lc['country'] == 'Saudi Arabia', :]
kuwait_lc = df_lc.loc[df_lc['country'] == 'Kuwait', :]
uae_lc = df_lc.loc[df_lc['country'] == 'United Arab Emirates', :]
bahrain_lc = df_lc.loc[df_lc['country'] == 'Bahrain', :]
qatar_lc = df_lc.loc[df_lc['country'] == 'Qatar', :]
oman_lc = df_lc.loc[df_lc['country'] == 'Oman', :]
#all are represented
# yippe they are

#lets see them together
gcc_lc = df_lc.loc[df_lc['country'].isin(['Saudi Arabia', 'United Arab Emirates', 'Qatar', 'Kuwait', 'Bahrain', 'Oman'])]

#order them
gcc_lc =gcc_lc.sort_values(by='purch_power', ascending=False)
gcc_lc

print('-'*50)
print('Cost of living')
print('-'*50)
print(f"""
{gcc_lc}

This gives us quality of life information for GCC countries

""")
#
#
# Out:
# --------------------------------------------------
# Cost of living
# --------------------------------------------------
#
#                  country  living_cost  purch_power
# 30                 Qatar        64.04       111.69
# 56          Saudi Arabia        48.34       100.00
# 31  United Arab Emirates        61.98        91.58
# 50                Kuwait        50.37        85.59
# 54                  Oman        49.28        80.97
# 34               Bahrain        58.94        57.88
#
# This gives us quality of life information for GCC countries

# %%
'Cost of Living and Quality of Life tables merged'



merged_lc_lq = pd.merge(gcc_lc, gcc_lq, on='country',how='left')
merged_lc_lq




print('-'*50)
print('Cost of living & quality of life')
print('-'*50)
print(f"""
{merged_lc_lq}

This gives us quality of life and cost of living information for GCC countries

""")
#
#
# Out:
# --------------------------------------------------
# Cost of living & quality of life
# --------------------------------------------------
#
#                 country  living_cost  purch_power  life_quality
# 0                 Qatar        64.04       111.69        162.29
# 1          Saudi Arabia        48.34       100.00        150.56
# 2  United Arab Emirates        61.98        91.58        156.67
# 3                Kuwait        50.37        85.59        115.75
# 4                  Oman        49.28        80.97        167.09
# 5               Bahrain        58.94        57.88        156.67
#
# This gives us quality of life and cost of living information for GCC countries

# %%
'Country metrix'

#merge all indexes
gcc_metrix = pd.merge(gcc_pop_market, merged_lc_lq, on='country', how='left')


#replace values
gcc_metrix = gcc_metrix.replace({'%change': {'3.68 %': '3.68','2.65 %': '2.65','1.73 %':'1.73','1.59 %':'1.59','1.51 %':'1.51','1.23 %':'1.23'}})

#change datatypes
gcc_metrix['pop'] = gcc_metrix['pop'].str.replace(',','').astype(float)
gcc_metrix['%change'] = gcc_metrix['%change'].astype(float)
gcc_metrix['med_age'] = gcc_metrix['med_age'].astype(float)
gcc_metrix['migrants'] = gcc_metrix['migrants'].str.replace(',','').astype(float)


#correlation table
gcc_metrix_corr = gcc_metrix.corr()
gcc_metrix_corr

# %%
merged_lc_lq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country       6 non-null      object
#  1   living_cost   6 non-null      float64
#  2   purch_power   6 non-null      float64
#  3   life_quality  6 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 240.0+ bytes

# %%
'Country metrix'

#merge all indexes
gcc_metrix = pd.merge(gcc_pop_market, merged_lc_lq, on='country', how='left')


#replace values
gcc_metrix = gcc_metrix.replace({'%change': {'3.68 %': '3.68','2.65 %': '2.65','1.73 %':'1.73','1.59 %':'1.59','1.51 %':'1.51','1.23 %':'1.23'}})

#change datatypes
gcc_metrix['pop'] = gcc_metrix['pop'].str.replace(',','').astype(float)
gcc_metrix['%change'] = gcc_metrix['%change'].astype(float)
gcc_metrix['med_age'] = gcc_metrix['med_age'].astype(float)
gcc_metrix['migrants'] = gcc_metrix['migrants'].str.replace(',','').astype(float)


#correlation table
gcc_metrix_corr = gcc_metrix.corr()
gcc_metrix_corr
# Out:
#                    pop   %change   med_age  migrants  living_cost  \
# pop           1.000000 -0.383840 -0.169384  0.855061    -0.474140
# %change      -0.383840  1.000000 -0.423681 -0.025047    -0.003302
# med_age      -0.169384 -0.423681  1.000000 -0.419181    -0.173284
# migrants      0.855061 -0.025047 -0.419181  1.000000    -0.695134
# living_cost  -0.474140 -0.003302 -0.173284 -0.695134     1.000000
# purch_power   0.369882 -0.801067 -0.006118  0.162356     0.144065
# life_quality -0.012889  0.349945 -0.962589  0.197083     0.368968
#
#               purch_power  life_quality
# pop              0.369882     -0.012889
# %change         -0.801067      0.349945
# med_age         -0.006118     -0.962589
# migrants         0.162356      0.197083
# living_cost      0.144065      0.368968
# purch_power      1.000000      0.049630
# life_quality     0.049630      1.000000

# %%
sns.heatmap(gcc_metrix_corr,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Country demographics

# %%
'Age demographics of GCC'

df_age_s = pd.DataFrame(country_age_structure.copy())
df_age_s

# rename / select the data
df_age_s['country'] = df_age_s['Country']
df_age_s['0_to_14'] = df_age_s['Age 0 to 14 Years']
df_age_s['15_to_64'] = df_age_s['Age 15 to 64 Years']
df_age_s['64_and_above'] = df_age_s['Age above 65 Years']
df_age_s

#dropping the ones we dont want
df_age_s = df_age_s.drop(columns=['Country','Age 0 to 14 Years','Age 15 to 64 Years','Age above 65 Years'])

#now we select the GCC countries
#lets see if any are not in data

saudi_age_s = df_age_s.loc[df_age_s['country'] == 'Saudi Arabia', :]
kuwait_age_s = df_age_s.loc[df_age_s['country'] == 'Kuwait', :]
uae_age_s = df_age_s.loc[df_age_s['country'] == 'United Arab Emirates', :]
bahrain_age_s = df_age_s.loc[df_age_s['country'] == 'Bahrain', :]
qatar_age_s = df_age_s.loc[df_age_s['country'] == 'Qatar', :]
oman_age_s = df_age_s.loc[df_age_s['country'] == 'Oman', :]
#all are represented

#lets see them together
gcc_age_s = df_age_s.loc[df_age_s['country'].isin(['Saudi Arabia', 'United Arab Emirates', 'Qatar', 'Kuwait', 'Bahrain', 'Oman'])]
                                                                

#order them
gcc_age_s =gcc_age_s.sort_values(by='0_to_14', ascending=False)
gcc_age_s

print('-'*50)
print('Age demographics of GCC')
print('-'*50)
print(f"""
{gcc_age_s}

This gives us the age demographics for GCC countries

""")
# Out:
# --------------------------------------------------
# Age demographics of GCC
# --------------------------------------------------
#
#                   country 0_to_14 15_to_64 64_and_above
# 148          Saudi Arabia  25.20%   71.50%           3%
# 182                  Oman  21.80%   75.80%           2%
# 187                Kuwait  21.10%   76.60%           2%
# 184               Bahrain  19.70%   77.90%           2%
# 189                 Qatar  13.90%   84.80%           1%
# 190  United Arab Emirates  13.90%   85.00%           1%
#
# This gives us the age demographics for GCC countries

# %% [markdown]
# # products in the gcc region

# %%
'(6) DataCoSupplyChainDataset'
### useful ###

DataCoSupplyChainDataset = pd.read_csv('DataCoSupplyChainDataset.csv', low_memory = False, encoding='ISO-8859-1' )
DataCoSupplyChainDataset.head()
DataCoSupplyChainDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
#'DataCoSupplyChainDataset'
#
# I want to see all the different product types that are in all the different
# GCC regions
#
df_scd = pd.DataFrame(DataCoSupplyChainDataset.copy())
df_scd

# rename / select the data
df_scd['product_category'] = df_scd['Category Name']
df_scd['customer_country'] = df_scd['Customer Country']
df_scd['sales'] = df_scd['Sales']
df_scd['order_country'] = df_scd['Order Country']
df_scd['dept'] = df_scd['Order Country']
df_scd

#rounding sales
df_scd['sales']=df_scd['sales'].round()

#call the columns you need
df_scd_1 = df_scd[['product_category','order_country','sales']]
df_scd_1.head()

#create a dataframe of gcc countries
#lets see what countries are represented

gcc_list =['Qatar','Baréin','Arabia Saudí','Omán','Kuwait','Emiratos Árabes Unidos']

# filter the DataFrame to keep only orders from the GCC region countries
df_gcc_product_sales = df_scd_1[df_scd['order_country'].isin(gcc_list)]
df_gcc_product_sales


#lets count to see how many products are bought in every country
# Out:
#         product_category order_country  sales
# 242       Men's Footwear  Arabia Saudí  130.0
# 252       Men's Footwear  Arabia Saudí  130.0
# 460     Cardio Equipment  Arabia Saudí  300.0
# 850               Cleats  Arabia Saudí   60.0
# 869       Men's Footwear  Arabia Saudí  130.0
# ...                  ...           ...    ...
# 177334   Women's Apparel  Arabia Saudí  150.0
# 177362  Cardio Equipment  Arabia Saudí  300.0
# 177391   Women's Apparel  Arabia Saudí  150.0
# 179209    Men's Footwear  Arabia Saudí  130.0
# 179212  Camping & Hiking  Arabia Saudí  300.0
#
# [945 rows x 3 columns]

# %%
#lets see the total sales of each country

df_gcc_sales = df_gcc_product_sales.groupby('order_country')['sales'].sum().reset_index()


df_gcc_sales=df_gcc_sales.sort_values(by='sales',ascending=False)
print('-'*50)
print('Total Sales of each country')
print('-'*50)
print(f"""
{df_gcc_sales}
""")
# Out:
# --------------------------------------------------
# Total Sales of each country
# --------------------------------------------------
#
#             order_country     sales
# 0            Arabia Saudí  163169.0
# 5                   Qatar    7725.0
# 2  Emiratos Árabes Unidos    5691.0
# 4                    Omán    1375.0
# 1                  Baréin     530.0
# 3                  Kuwait     335.0

# %%
#lets count to see how many products are bought in every country

products_per_country = df_gcc['order_country'].value_counts()
print('-'*50)
print('Total types products bought')
print('-'*50)
print(f"""
{products_per_country}
""")
# Out:
# --------------------------------------------------
# Total types products bought
# --------------------------------------------------
#
# Arabia Saudí              860
# Qatar                      42
# Emiratos Árabes Unidos     29
# Omán                        8
# Baréin                      4
# Kuwait                      2
# Name: order_country, dtype: int64

# %%
#we want to see the list of each countries products
countries = df_gcc['order_country'].unique()

#make a dictionary to store this stuff
country_dfs = {}

for country in countries:
    country_df = df_gcc[df_gcc['order_country'] == country]
    sales_by_product = country_df.pivot_table(index='product_category', values='sales', aggfunc='count')
    country_dfs[country] = sales_by_product
#lets see if it works
country_dfs['Qatar']
#cool it works
country_dfs
# Out:
# {'Arabia Saudí':                       sales
#  product_category
#  Accessories              11
#  Baseball & Softball       1
#  Boxing & MMA              2
#  Camping & Hiking         68
#  Cardio Equipment         57
#  Cleats                  122
#  Electronics              18
#  Fishing                  82
#  Fitness Accessories       3
#  Girls' Apparel            6
#  Golf Apparel              2
#  Golf Balls                8
#  Golf Gloves               5
#  Golf Shoes                1
#  Hockey                    5
#  Hunting & Shooting        1
#  Indoor/Outdoor Games     99
#  Lacrosse                  3
#  Men's Footwear          114
#  Shop By Sport            65
#  Tennis & Racquet          1
#  Trade-In                  6
#  Water Sports             77
#  Women's Apparel         103,
#  'Emiratos Árabes Unidos':                       sales
#  product_category
#  Camping & Hiking          2
#  Cleats                    5
#  Electronics               1
# ...

# %%
tmp_summary = df_gcc.pivot_table(index="order_country", columns= "product_category", values= "sales",aggfunc=('sum'))
tmp_summary

tmp_summary.plot(kind="barh")
# Out:
# <AxesSubplot: ylabel='order_country'>

# %%
print('-'*100)
print('Products sold in Qatar')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Products sold in Qatar
# --------------------------------------------------

# %%
#Total products sold in Qatar
product_summary_qatar = country_dfs['Qatar'].pivot_table(index="product_category",values= "sales",aggfunc=('sum'))
product_summary_qatar
# Out:
#                       sales
# product_category
# Camping & Hiking          1
# Cardio Equipment          5
# Cleats                    6
# Electronics               2
# Fishing                   5
# Hunting & Shooting        1
# Indoor/Outdoor Games      3
# Men's Footwear            5
# Shop By Sport             3
# Tennis & Racquet          1
# Water Sports              3
# Women's Apparel           7

# %%
product_summary_qatar.plot(kind="barh", title = 'Total Products sold in Qatar')
# Out:
# <AxesSubplot: title={'center': 'Total Products sold in Qatar'}, ylabel='product_category'>

# %%
print('-'*100)
print('Products sold in Oman')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Products sold in Oman
# --------------------------------------------------

# %%
#Total products sold in Oman
product_summary_oman = country_dfs['Omán'].pivot_table(index="product_category",values= "sales",aggfunc=('sum'))
product_summary_oman
# Out:
#                       sales
# product_category
# Baseball & Softball       1
# Cleats                    1
# Indoor/Outdoor Games      2
# Men's Footwear            4

# %%
product_summary_oman.plot(kind="barh", title = 'Total Products sold in Omán')
# Out:
# <AxesSubplot: title={'center': 'Total Products sold in Omán'}, ylabel='product_category'>

# %%
print('-'*100)
print('Products sold in Kuwait')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Products sold in Kuwait
# --------------------------------------------------

# %%
#Total products sold in Kuwait
product_summary_kuwait = country_dfs['Kuwait'].pivot_table(index="product_category",values= "sales",aggfunc=('sum'))
product_summary_kuwait
# Out:
#                   sales
# product_category
# Electronics           1
# Water Sports          1

# %%
product_summary_kuwait.plot(kind="barh", title = 'Total Products sold in Kuwait')
# Out:
# <AxesSubplot: title={'center': 'Total Products sold in Kuwait'}, ylabel='product_category'>

# %%
print('-'*100)
print('Products sold in United Arab Emirates')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Products sold in United Arab Emirates
# --------------------------------------------------

# %%
#Total products sold in Emiratos Árabes Unidos
product_summary_uae = country_dfs['Emiratos Árabes Unidos'].pivot_table(index="product_category",values= "sales",aggfunc=('sum'))
product_summary_uae
# Out:
#                       sales
# product_category
# Camping & Hiking          2
# Cleats                    5
# Electronics               1
# Fishing                   5
# Fitness Accessories       1
# Girls' Apparel            1
# Golf Gloves               2
# Hunting & Shooting        1
# Indoor/Outdoor Games      2
# Men's Footwear            3
# Shop By Sport             1
# Water Sports              2
# Women's Apparel           3

# %%
product_summary_uae.plot(kind="barh", title = 'Total Products sold in Emiratos Árabes Unidos')
# Out:
# <AxesSubplot: title={'center': 'Total Products sold in Emiratos Árabes Unidos'}, ylabel='product_category'>

# %%
print('-'*100)
print('Products sold in Bahrain')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Products sold in Bahrain
# --------------------------------------------------

# %%
#Total products sold in Baréin
product_summary_bahrain = country_dfs['Baréin'].pivot_table(index="product_category",values= "sales",aggfunc=('sum'))
product_summary_bahrain
# Out:
#                   sales
# product_category
# Men's Footwear        2
# Shop By Sport         1
# Trade-In              1

# %%
product_summary_bahrain.plot(kind="barh", title = 'Total Products sold in Baréin')
# Out:
# <AxesSubplot: title={'center': 'Total Products sold in Baréin'}, ylabel='product_category'>

# %%
print('-'*100)
print('Products sold in Saudi Arabia')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Products sold in Saudi Arabia
# --------------------------------------------------

# %%
#Total products sold in Arabia Saudí
product_summary_saudi = country_dfs['Arabia Saudí'].pivot_table(index="product_category",values= "sales",aggfunc=('sum'))
product_summary_saudi
# Out:
#                       sales
# product_category
# Accessories              11
# Baseball & Softball       1
# Boxing & MMA              2
# Camping & Hiking         68
# Cardio Equipment         57
# Cleats                  122
# Electronics              18
# Fishing                  82
# Fitness Accessories       3
# Girls' Apparel            6
# Golf Apparel              2
# Golf Balls                8
# Golf Gloves               5
# Golf Shoes                1
# Hockey                    5
# Hunting & Shooting        1
# Indoor/Outdoor Games     99
# Lacrosse                  3
# Men's Footwear          114
# Shop By Sport            65
# Tennis & Racquet          1
# Trade-In                  6
# Water Sports             77
# Women's Apparel         103

# %%
product_summary_saudi.plot(kind="barh", title = 'Total Products sold in Arabia Saudí')
# Out:
# <AxesSubplot: title={'center': 'Total Products sold in Arabia Saudí'}, ylabel='product_category'>

# %% [markdown]
# # Problem Solving
#
# This section needs to guide throught the problem solving process and make it clear how the results have been derived from the data. It should also contain executable code for everything that is code based. Code cells need to be executable top-to-bottom and be well commented.
#
#
# Needs to be clear and understanding
# - If you need to have a specific merging that answers a question will put it here

# %%
print('''
Based off the findings from above, we can narrow our search from 6 countries down to 3 countries
    
    1. Saudi Arabia
    2. Qatar
    3. United Arab emirated
    
    
    
reasons why we dropped the others/kept these
    - There is not enough data to from the other three countries
    - Sales from the 3 we picked were signifantly higher
    - All three of those countries are close enough to each other than shipping \
    \n\tfrom qatar to uae or uae to saudi is not a far distance and the closest of\
    \n\tthe six


''')
print('-'*100)
# Out:
# Based off the findings from above, we can narrow our search from 6 countries down to 3 countries
#
#     1. Saudi Arabia
#     2. Qatar
#     3. United Arab emirated
#
#
#
# reasons why we dropped the others/kept these
#     - There is not enough data to from the other three countries
#     - Sales from the 3 we picked were signifantly higher
#     - All three of those countries are close enough to each other than shipping
# 	from qatar to uae or uae to saudi is not a far distance and the closest of
# 	the six
#
#
#
# ----------------------------------------------------------------------------------------------------

# %%
print('-'*100)
print('UAE, Saudi Arabia, and Qatart population metrix')
print('-'*100)
print(f'''
{gcc_metrix_9}''')
# Out:
# ----------------------------------------------------------------------------------------------------
# UAE, Saudi Arabia, and Qatart population metrix
# ----------------------------------------------------------------------------------------------------
#
#                              pop  %change  med_age  migrants  living_cost  \
# country
# Qatar                  2889284.0     1.73     32.0   40000.0        64.04
# Saudi Arabia          34905942.0     1.59     32.0  134979.0        48.34
# United Arab Emirates   9910892.0     1.23     33.0   40000.0        61.98
#
#                       purch_power  life_quality
# country
# Qatar                      111.69        162.29
# Saudi Arabia               100.00        150.56
# United Arab Emirates        91.58        156.67

# %%
print('''What is the correlation of the  population metrix of the just the three countries?''')
# Out:
# What is the correlation of the  population metrix of the just the three countries?

# %%
#lets see the correlation between only the 3 countries
gcc_metrix_9 = gcc_metrix.T
gcc_metrix_9 = gcc_metrix_9.set_axis(gcc_metrix_9.iloc[0], axis=1).iloc[1:]
gcc_metrix_9

gcc_metrix_9 = gcc_metrix_9.drop(columns=['Oman','Kuwait','Bahrain'])
gcc_metrix_9 = gcc_metrix_9.T


gcc_metrix_9['pop'] = gcc_metrix_9['pop'].astype(float)
gcc_metrix_9['%change'] = gcc_metrix_9['%change'].astype(float)
gcc_metrix_9['med_age'] = gcc_metrix_9['med_age'].astype(float)
gcc_metrix_9['migrants'] = gcc_metrix_9['migrants'].astype(float)
gcc_metrix_9['living_cost'] = gcc_metrix_9['living_cost'].astype(float)
gcc_metrix_9['purch_power'] = gcc_metrix_9['purch_power'].astype(float)
gcc_metrix_9['life_quality'] = gcc_metrix_9['life_quality'].astype(float)

gcc_metrix_9_corr=gcc_metrix_9.corr()
gcc_metrix_9_corr
# Out:
#                    pop   %change   med_age  migrants  living_cost  \
# pop           1.000000  0.038592 -0.308322  0.977995    -0.996028
# %change       0.038592  1.000000 -0.962472  0.246214    -0.127409
# med_age      -0.308322 -0.962472  1.000000 -0.500000     0.391797
# migrants      0.977995  0.246214 -0.500000  1.000000    -0.992687
# living_cost  -0.996028 -0.127409  0.391797 -0.992687     1.000000
# purch_power  -0.299126  0.941959 -0.815499 -0.093469     0.212978
# life_quality -0.958440  0.248096  0.024111 -0.877829     0.929231
#
#               purch_power  life_quality
# pop             -0.299126     -0.958440
# %change          0.941959      0.248096
# med_age         -0.815499      0.024111
# migrants        -0.093469     -0.877829
# living_cost      0.212978      0.929231
# purch_power      1.000000      0.558927
# life_quality     0.558927      1.000000

# %%
sns.heatmap(gcc_metrix_9_corr,cmap='coolwarm')
plt.show()

# %%
gcc_age_s_3 = gcc_age_s[gcc_age_s['country'].isin(['Qatar', 'United Arab Emirates', 'Saudi Arabia'])]


print('-'*100)
print('Age structures of SA, UAE, & Qatar')
print('-'*25)
print(f"""
{gcc_age_s_3}

""")
print('-'*50)
print('''From this, we can conclude that we are wanting to focus on saudi arabia because although\
\nthey have the largest senior citizen % they also have the largest children''')
print('-'*50)
# Out:
# ----------------------------------------------------------------------------------------------------
# Age structures of SA, UAE, & Qatar
# -------------------------
#
#                   country 0_to_14 15_to_64 64_and_above
# 148          Saudi Arabia  25.20%   71.50%           3%
# 189                 Qatar  13.90%   84.80%           1%
# 190  United Arab Emirates  13.90%   85.00%           1%
#
#
# --------------------------------------------------
# From this, we can conclude that we are wanting to focus on saudi arabia because although
# they have the largest senior citizen % they also have the largest children
# --------------------------------------------------

# %%
print('-'*50)
print('Total Sales of each country')
print('-'*25)
print(f"""
{df_gcc_sales}
""")
# Out:
# --------------------------------------------------
# Total Sales of each country
# -------------------------
#
#             order_country     sales
# 0            Arabia Saudí  163169.0
# 5                   Qatar    7725.0
# 2  Emiratos Árabes Unidos    5691.0
# 4                    Omán    1375.0
# 1                  Baréin     530.0
# 3                  Kuwait     335.0

# %%
merged_df_v = merged_df.T
merged_df_v.columns.name = 'product_category'
merged_df_v


print('-'*25)
print('Total types products bought in only the three')
print('-'*25)
print(f"""
{merged_df_v}
""")
print('-'*25)
print('''
Based on the charts above, we can determine that we do not have enough data to\
\nexplore the option of expanding our sales efforts to Bahrain, Kuwait, or Oman
\n\nThe obvious choice is to expand our Saudi network, but should see if there\
\nare similar products that we could focus on with UAE and Qatar
''')
print('-'*100)
# Out:
# -------------------------
# Total types products bought in only the three
# -------------------------
#
# product_category  sales_uae  sales_qatar  saudi_sales
# product_category
# camping_hiking            2            1           68
# cleats                    5            6          122
# electronics               1            2           18
# fishing                   5            5           82
# hunting_shooting          1            1            1
# in_out_games              2            3           99
# men_shoes                 3            5          114
# shop_by_sports            1            3           65
# water_sports              2            3           77
# women_shoes               3            7          103
#
# -------------------------
#
# Based on the charts above, we can determine that we do not have enough data to
# explore the option of expanding our sales efforts to Bahrain, Kuwait, or Oman
#
#
# ...

# %%
#lets see only the 3 countries and similar products
merged_df = product_summary_uae.merge(product_summary_qatar, on='product_category',suffixes=('_uae','_qatar'))
merged_df = merged_df.merge(product_summary_saudi, on='product_category')

merged_df['saudi_sales'] = merged_df['sales']
merged_df = merged_df.drop(columns=['sales'])

#transpose and fix the data we have
merged_df = merged_df.T
merged_df.columns.name = 'product_category'
merged_df


#rename
merged_df['camping_hiking'] = merged_df['Camping & Hiking']
merged_df['cleats'] = merged_df['Cleats']
merged_df['electronics'] = merged_df['Electronics']
merged_df['fishing'] = merged_df['Fishing']
merged_df['hunting_shooting'] = merged_df['Hunting & Shooting']
merged_df['in_out_games'] = merged_df['Indoor/Outdoor Games']
merged_df['men_shoes'] = merged_df['Men\'s Footwear']
merged_df['shop_by_sports'] = merged_df['Shop By Sport']
merged_df['water_sports'] = merged_df['Water Sports']
merged_df['women_shoes'] = merged_df['Women\'s Apparel']

#drop those columns
merged_df = merged_df.drop(columns=['Camping & Hiking','Cleats','Electronics',\
                                    'Fishing','Hunting & Shooting','Indoor/Outdoor Games',\
                                   'Men\'s Footwear','Shop By Sport','Water Sports','Women\'s Apparel'])


merged_df
# Out:
# product_category  camping_hiking  cleats  electronics  fishing  \
# sales_uae                      2       5            1        5
# sales_qatar                    1       6            2        5
# saudi_sales                   68     122           18       82
#
# product_category  hunting_shooting  in_out_games  men_shoes  shop_by_sports  \
# sales_uae                        1             2          3               1
# sales_qatar                      1             3          5               3
# saudi_sales                      1            99        114              65
#
# product_category  water_sports  women_shoes
# sales_uae                    2            3
# sales_qatar                  3            7
# saudi_sales                 77          103

# %%
#correlation table for procuts
merged_df_corr = merged_df.corr()
merged_df_corr

sns.heatmap(merged_df_corr,cmap='coolwarm')
plt.show()

# %%
print('''Since all the products from the three countries are highly correlated, there is\
\nno reason for us to group products when advertising. Focusing on any pairs of products will\
\nbe just as benefitial as being mythotical about it.''')
print('-'*50)
# Out:
# Since all the products from the three countries are highly correlated, there is
# no reason for us to group products when advertising. Focusing on any pairs of products will
# be just as benefitial as being mythotical about it.
# --------------------------------------------------
